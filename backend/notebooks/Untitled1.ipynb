# %%
# !pwd
# Out:
# /home/alec/code/alecmatt5/nba_betting_analysis/nba_betting_analysis/backend/notebooks

# %%
import pandas as pd

# %%
advanced = pd.read_pickle('../data/pkl/boxscores_advanced_team_all.pkl')

# %%
advanced['TEAM_CITY'].un
# Out:
# 0        Indiana
# 1        Chicago
# 2        Phoenix
# 3         Dallas
# 4    Los Angeles
#         ...
# 1        Orlando
# 0        Phoenix
# 1      Milwaukee
# 0       Portland
# 1       New York
# Name: TEAM_CITY, Length: 12874, dtype: object

# %%
from nba_api.stats.endpoints import scoreboard

# %%
dates = ['03-12-2023', '03-13-2023', '03-14-2023']

# %%
games
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2023-03-12T00:00:00              1  0022201014               3
# 1  2023-03-12T00:00:00              2  0022201015               3
# 2  2023-03-12T00:00:00              3  0022201016               3
# 3  2023-03-12T00:00:00              4  0022201017               3
# 4  2023-03-12T00:00:00              5  0022201018               3
# 5  2023-03-12T00:00:00              6  0022201019               3
# 0  2023-03-13T00:00:00              1  0022201020               3
# 1  2023-03-13T00:00:00              2  0022201021               3
# 2  2023-03-13T00:00:00              3  0022201022               3
# 3  2023-03-13T00:00:00              4  0022201023               3
# 4  2023-03-13T00:00:00              5  0022201024               3
# 5  2023-03-13T00:00:00              6  0022201025               3
# 6  2023-03-13T00:00:00              7  0022201026               3
# ...
