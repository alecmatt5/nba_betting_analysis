# %%
import pandas as pd
import numpy as np

# %%
boxscores_advanced = pd.read_pickle('boxscores_advanced_team_2000.pkl')

# %%
boxscores_advanced.head()
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION     TEAM_CITY     MIN  \
# 4  0022200973  1610612764   Wizards               WAS    Washington  240:00
# 5  0022200973  1610612749     Bucks               MIL     Milwaukee  240:00
# 6  0022200964  1610612747    Lakers               LAL   Los Angeles  240:00
# 7  0022200964  1610612744  Warriors               GSW  Golden State  240:00
# 8  0022200962  1610612756      Suns               PHX       Phoenix  240:00
#
#    E_OFF_RATING  OFF_RATING  E_DEF_RATING  DEF_RATING  ...  TM_TOV_PCT  \
# 4         108.5       111.0         119.8       114.7  ...         9.0
# 5         119.8       114.7         108.5       111.0  ...        11.8
# 6         109.0       114.1         100.1       106.1  ...         9.1
# 7         100.1       106.1         109.0       114.1  ...        13.1
# 8         130.0       134.0         127.6       128.6  ...         9.3
#
#    EFG_PCT  TS_PCT  USG_PCT  E_USG_PCT  E_PACE   PACE  PACE_PER40  POSS    PIE
# ...

# %%
boxscores_advanced.iloc[::2].reset_index(drop=True)
# Out:
#         GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION     TEAM_CITY     MIN  \
# 0    0022200973  1610612764   Wizards               WAS    Washington  240:00
# 1    0022200964  1610612747    Lakers               LAL   Los Angeles  240:00
# 2    0022200962  1610612756      Suns               PHX       Phoenix  240:00
# 3    0022200963  1610612754    Pacers               IND       Indiana  240:00
# 4    0022200967  1610612759     Spurs               SAS   San Antonio  240:00
# ..          ...         ...       ...               ...           ...     ...
# 993  0012200049  1610612749     Bucks               MIL     Milwaukee  240:00
# 994  0012200043  1610612764   Wizards               WAS    Washington  240:00
# 995  0012200046  1610612756      Suns               PHX       Phoenix  240:00
# 996  0012200045  1610612748      Heat               MIA         Miami  240:00
# 997  0012200044  1610612755     76ers               PHI  Philadelphia  240:00
#
# ...

# %%
boxscores_advanced.iloc[1::2].reset_index(drop=True)
# Out:
#         GAME_ID     TEAM_ID  TEAM_NAME TEAM_ABBREVIATION     TEAM_CITY  \
# 0    0022200973  1610612749      Bucks               MIL     Milwaukee
# 1    0022200964  1610612744   Warriors               GSW  Golden State
# 2    0022200962  1610612742  Mavericks               DAL        Dallas
# 3    0022200963  1610612741      Bulls               CHI       Chicago
# 4    0022200967  1610612745    Rockets               HOU       Houston
# ..          ...         ...        ...               ...           ...
# 993  0012200049  1610612741      Bulls               CHI       Chicago
# 994  0012200043  1610612766    Hornets               CHA     Charlotte
# 995  0012200046  1610612743    Nuggets               DEN        Denver
# 996  0012200045  1610612745    Rockets               HOU       Houston
# 997  0012200044  1610612739  Cavaliers               CLE     Cleveland
#
#         MIN  E_OFF_RATING  OFF_RATING  E_DEF_RATING  DEF_RATING  ...  \
# ...
